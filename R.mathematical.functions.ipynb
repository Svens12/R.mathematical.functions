# %%
x<-c(4.258,-3.853,5.457,7.504)
abs(x)
# Out:
# [1] 4.258 3.853 5.457 7.504

# %%
ceiling(x)
# Out:
# [1]  5 -3  6  8

# %%
floor(x)
# Out:
# [1]  4 -4  5  7

# %%
round(x)
# Out:
# [1]  4 -4  5  8

# %%
round(x,2)
# Out:
# [1]  4.26 -3.85  5.46  7.50

# %%
trunc(x)
# Out:
# [1]  4 -3  5  7

# %%
x<-c(16,36,30,81,25)

# %%
sqrt(x)
# Out:
# [1] 4.000000 6.000000 5.477226 9.000000 5.000000

# %%
exp(x)
# Out:
# [1] 8.886111e+06 4.311232e+15 1.068647e+13 1.506097e+35 7.200490e+10

# %%
log(x)
# Out:
# [1] 2.772589 3.583519 3.401197 4.394449 3.218876

# %%
log(x,base=2)
# Out:
# [1] 4.000000 5.169925 4.906891 6.339850 4.643856

# %%
log2(x)
# Out:
# [1] 4.000000 5.169925 4.906891 6.339850 4.643856

# %%
log(x,base=10)
# Out:
# [1] 1.204120 1.556303 1.477121 1.908485 1.397940

# %%
log10(x)
# Out:
# [1] 1.204120 1.556303 1.477121 1.908485 1.397940

# %%
x<-c(4,3,6)
factorial(x)
# Out:
# [1]  24   6 720
